# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("C://Users//shash//Downloads//List of Countries by Sugarcane Production (1).csv")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df.shape
# Out:
# (103, 7)

# %% [markdown]
# DATA CLEANING

# %%
df["Production (Tons)"]=df["Production (Tons)"].str.replace(".","")
df["Production per Person (Kg)"]=df["Production per Person (Kg)"].str.replace(".","").str.replace(",",".")
df["Acreage (Hectare)"]=df["Acreage (Hectare)"].str.replace(".",",")
df["Yield (Kg / Hectare)"]=df["Yield (Kg / Hectare)"].str.replace(",",".").str.replace(",",".")
# Out:
# C:\Users\shash\AppData\Local\Temp\ipykernel_20840\2883038600.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Production (Tons)"]=df["Production (Tons)"].str.replace(".","")
# C:\Users\shash\AppData\Local\Temp\ipykernel_20840\2883038600.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Production per Person (Kg)"]=df["Production per Person (Kg)"].str.replace(".","").str.replace(",",".")
# C:\Users\shash\AppData\Local\Temp\ipykernel_20840\2883038600.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Acreage (Hectare)"]=df["Acreage (Hectare)"].str.replace(".",",")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                    3668531          10226205              75167.5
# 1                     260721           4950000              70393.5
# 2                      88287           1675215              73459.1
# 3                    1264303           1336575              65442.2
# 4                     324219           1130820                57879

# %%
df.rename(columns={"Production(Tons)":"Production(Tons)"},inplace=True)
df.rename(columns={"Production per Person (Kg)":"Production_per_Person_(Kg)"},inplace=True)
df.rename(columns={"Acreage (Hectare)":"Acreage(Hectare)"},inplace=True)
df.rename(columns={"Yield (Kg / Hectare)":"Yield(Kg/Hectare)"},inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production_per_Person_(Kg) Acreage(Hectare) Yield(Kg/Hectare)
# 0                    3668531         10226205           75167.5
# 1                     260721          4950000           70393.5
# 2                      88287          1675215           73459.1
# 3                    1264303          1336575           65442.2
# 4                     324219          1130820             57879

# %%
df.isna().sum()
# Out:
# Unnamed: 0                    0
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production_per_Person_(Kg)    0
# Acreage(Hectare)              1
# Yield(Kg/Hectare)             1
# dtype: int64

# %%
df[df["Acreage(Hectare)"].isnull()]
# Out:
#     Unnamed: 0   Country Continent Production (Tons)  \
# 99          99  Djibouti    Africa                53
#
#    Production_per_Person_(Kg) Acreage(Hectare) Yield(Kg/Hectare)
# 99                         51              NaN               NaN

# %%
df=df.dropna().reset_index()

# %%
df.head()
# Out:
#    index  Unnamed: 0   Country      Continent Production (Tons)  \
# 0      0           0    Brazil  South America         768678382
# 1      1           1     India           Asia         348448000
# 2      2           2     China           Asia         123059739
# 3      3           3  Thailand           Asia          87468496
# 4      4           4  Pakistan           Asia          65450704
#
#   Production_per_Person_(Kg) Acreage(Hectare) Yield(Kg/Hectare)
# 0                    3668531         10226205           75167.5
# 1                     260721          4950000           70393.5
# 2                      88287          1675215           73459.1
# 3                    1264303          1336575           65442.2
# 4                     324219          1130820             57879

# %%
df.drop(["index","Unnamed: 0"],axis=1,inplace=True)

# %%
df.head()
# Out:
#     Country      Continent Production (Tons) Production_per_Person_(Kg)  \
# 0    Brazil  South America         768678382                    3668531
# 1     India           Asia         348448000                     260721
# 2     China           Asia         123059739                      88287
# 3  Thailand           Asia          87468496                    1264303
# 4  Pakistan           Asia          65450704                     324219
#
#   Acreage(Hectare) Yield(Kg/Hectare)
# 0         10226205           75167.5
# 1          4950000           70393.5
# 2          1675215           73459.1
# 3          1336575           65442.2
# 4          1130820             57879

# %%
df.dtypes
# Out:
# Country                       object
# Continent                     object
# Production (Tons)             object
# Production_per_Person_(Kg)    object
# Acreage(Hectare)              object
# Yield(Kg/Hectare)             object
# dtype: object

# %%
df["Production (Tons)"]=df["Production (Tons)"].astype(float)
df["Production_per_Person_(Kg)"]=df["Production_per_Person_(Kg)"].astype(float)
df["Acreage(Hectare)"]=df["Acreage(Hectare)"].astype(float)
df["Yield(Kg/Hectare)"]=df["Yield(Kg/Hectare)"].astype(float)

# %%
df.dtypes
# Out:
# Country                        object
# Continent                      object
# Production (Tons)             float64
# Production_per_Person_(Kg)    float64
# Acreage(Hectare)              float64
# Yield(Kg/Hectare)             float64
# dtype: object

# %%
df.nunique()
# Out:
# Country                       102
# Continent                       6
# Production (Tons)             102
# Production_per_Person_(Kg)    101
# Acreage(Hectare)              101
# Yield(Kg/Hectare)             102
# dtype: int64

# %% [markdown]
# UNIVARITE ANALYSIS

# %%
df.head()
# Out:
#     Country      Continent  Production (Tons)  Production_per_Person_(Kg)  \
# 0    Brazil  South America        768678382.0                   3668531.0
# 1     India           Asia        348448000.0                    260721.0
# 2     China           Asia        123059739.0                     88287.0
# 3  Thailand           Asia         87468496.0                   1264303.0
# 4  Pakistan           Asia         65450704.0                    324219.0
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %%
df["Continent"].value_counts()
# Out:
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: Continent, dtype: int64

# %% [markdown]
# DISTRIBUTION OF THE COLUMNS

# %%
df["Continent"].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
CHECKING OUTLIERS

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.boxplot(df["Production (Tons)"])
plt.subplot(2,2,2)
sns.boxplot(df["Production_per_Person_(Kg)"])
plt.subplot(2,2,3)
sns.boxplot(df["Acreage(Hectare)"])
plt.subplot(2,2,4)
sns.boxplot(df["Yield(Kg/Hectare)"])
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        Production (Tons)  Production_per_Person_(Kg)  Acreage(Hectare)  \
# count       1.020000e+02                1.020000e+02      1.020000e+02
# mean        1.850372e+07                4.124805e+05      2.498981e+05
# std         8.419149e+07                8.669140e+05      1.137003e+06
# min         1.000000e+00                0.000000e+00      0.000000e+00
# 25%         6.251875e+04                1.075225e+04      1.104000e+03
# 50%         1.440044e+06                8.135850e+04      1.655800e+04
# 75%         6.426824e+06                2.828128e+05      8.047400e+04
# max         7.686784e+08                4.816299e+06      1.022620e+07
#
#        Yield(Kg/Hectare)
# count         102.000000
# mean        52628.078431
# std         30504.676683
# min            10.000000
# 25%         29072.025000
# 50%         54108.950000
# 75%         73282.700000
# max        129049.300000

# %% [markdown]
# BIVARIANTE ANALYSIS

# %%
df.head()
# Out:
#     Country      Continent  Production (Tons)  Production_per_Person_(Kg)  \
# 0    Brazil  South America        768678382.0                   3668531.0
# 1     India           Asia        348448000.0                    260721.0
# 2     China           Asia        123059739.0                     88287.0
# 3  Thailand           Asia         87468496.0                   1264303.0
# 4  Pakistan           Asia         65450704.0                    324219.0
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %%
df_new=df[["Country","Production (Tons)"]].set_index("Country")

# %%
df_new
# Out:
#            Production (Tons)
# Country
# Brazil           768678382.0
# India            348448000.0
# China            123059739.0
# Thailand          87468496.0
# Pakistan          65450704.0
# ...                      ...
# Spain                  394.0
# Lebanon                 97.0
# Singapore               50.0
# Samoa                   12.0
# Syria                    1.0
#
# [102 rows x 1 columns]

# %%
df_new["Production (Tons)_percent"]=df_new["Production (Tons)"]*100/df_new["Production (Tons)"].sum()

# %%
df_new
# Out:
#            Production (Tons)  Production (Tons)_percent
# Country
# Brazil           768678382.0               4.072729e+01
# India            348448000.0               1.846200e+01
# China            123059739.0               6.520138e+00
# Thailand          87468496.0               4.634389e+00
# Pakistan          65450704.0               3.467809e+00
# ...                      ...                        ...
# Spain                  394.0               2.087551e-05
# Lebanon                 97.0               5.139401e-06
# Singapore               50.0               2.649176e-06
# Samoa                   12.0               6.358022e-07
# Syria                    1.0               5.298352e-08
#
# [102 rows x 2 columns]

# %%
df_new["Production (Tons)_percent"].plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='Production (Tons)_percent'>

# %%
df_new["Production (Tons)"].head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %%
df.head(10)
# Out:
#                     Country      Continent  Production (Tons)  \
# 0                    Brazil  South America        768678382.0
# 1                     India           Asia        348448000.0
# 2                     China           Asia        123059739.0
# 3                  Thailand           Asia         87468496.0
# 4                  Pakistan           Asia         65450704.0
# 5                    Mexico  North America         56446821.0
# 6                  Colombia  South America         36951213.0
# 7                 Australia        Oceania         34403004.0
# 8                 Guatemala  North America         33533403.0
# 9  United States of America  North America         29926210.0
#
#    Production_per_Person_(Kg)  Acreage(Hectare)  Yield(Kg/Hectare)
# 0                   3668531.0        10226205.0            75167.5
# 1                    260721.0         4950000.0            70393.5
# 2                     88287.0         1675215.0            73459.1
# 3                   1264303.0         1336575.0            65442.2
# 4                    324219.0         1130820.0            57879.0
# 5                    452524.0          781054.0             7227.0
# 6                    740075.0          416626.0            88691.5
# 7                   1373406.0          447204.0            76929.1
# 8                   1938114.0           25985.0           129049.3
# 9                     91304.0           37053.0            80766.0

# %%
ax=sns.barplot(data=df.head(10),x="Country",y="Production (Tons)")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ax=sns.barplot(data=df.head(10),x="Country",y="Production (Tons)")
#       2 ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
#       3 plt.show()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# WHICH COUNTRY HAS THE HIGHEST LAND?

# %%
df_acr=df.sort_values("Acreage(Hectare)",ascending=False)
ax=sns.barplot(data=df_acr.head(10),x="Country",y="Acreage(Hectare)")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()

# %% [markdown]
# WHICH COUNTRY HAS HIGHEST YIELD PER HECTARE?

# %%
df_yield=df.sort_values("Yield(Kg/Hectare)",ascending=False)
ax=sns.barplot(data=df_yield.head(10),x="Country",y="Yield(Kg/Hectare)")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()

# %% [markdown]
# COORELATION

# %%
df.corr()
# Out:
# C:\Users\shash\AppData\Local\Temp\ipykernel_20840\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                             Production (Tons)  Production_per_Person_(Kg)  \
# Production (Tons)                    1.000000                    0.352369
# Production_per_Person_(Kg)           0.352369                    1.000000
# Acreage(Hectare)                     0.997550                    0.341974
# Yield(Kg/Hectare)                    0.132812                    0.220522
#
#                             Acreage(Hectare)  Yield(Kg/Hectare)
# Production (Tons)                   0.997550           0.132812
# Production_per_Person_(Kg)          0.341974           0.220522
# Acreage(Hectare)                    1.000000           0.113433
# Yield(Kg/Hectare)                   0.113433           1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\shash\AppData\Local\Temp\ipykernel_20840\4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# DO COUNTRY WITH HIGHEST LAND PRODUCTION MORE SUGARCANE?

# %%
sns.scatterplot(data=df, x="Acreage(Hectare)", y="Production (Tons)")
# Out:
# <Axes: xlabel='Acreage(Hectare)', ylabel='Production (Tons)'>

# %% [markdown]
# DO COUNTRIES WHICH YEILD MORE SUGARCANE PER HECTARE PRODUCERS MORE SUGARCANE IN TOTAL?

# %%
sns.scatterplot(data=df, x="Yield(Kg/Hectare)", y="Production (Tons)")
# Out:
# <Axes: xlabel='Yield(Kg/Hectare)', ylabel='Production (Tons)'>

# %% [markdown]
# ANALYSIS FOR CONTINENT

# %%
df_Continent=df.groupby("Continent").sum()
# Out:
# C:\Users\shash\AppData\Local\Temp\ipykernel_20840\30052407.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_Continent=df.groupby("Continent").sum()

# %%
df_Continent
# Out:
#                Production (Tons)  Production_per_Person_(Kg)  \
# Continent
# Africa                89681472.0                  10144110.0
# Asia                 721930425.0                   3120808.0
# Europe                    5823.0                       536.0
# North America        173995947.0                  15420953.0
# Oceania               36177574.0                   3158066.0
# South America        865588126.0                  10228540.0
#
#                Acreage(Hectare)  Yield(Kg/Hectare)
# Continent
# Africa                1439089.0          2142107.5
# Asia                 10608319.0          1171871.4
# Europe                     71.0           131870.9
# North America         1581983.0          1082602.4
# Oceania                490909.0           162419.1
# South America        11369236.0           677192.7

# %% [markdown]
# WHICH CONTINENT PRODUCES MAXIMUM SUGARCANE?

# %%
df["Continent"].value_counts()
# Out:
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: Continent, dtype: int64

# %%
df_Continent["Production (Tons)"].sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Continent'>

# %%
df_Continent["Acreage(Hectare)"].sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# DO NUMBER OF COUNTRIES IN A CONTINENT EFFECT PRODUCTION OF SUGARCANE?

# %%
df_Continent["number_of_countries"]=df.groupby("Continent").count()["Country"]

# %%
df_Continent
# Out:
#                Production (Tons)  Production_per_Person_(Kg)  \
# Continent
# Africa                89681472.0                  10144110.0
# Asia                 721930425.0                   3120808.0
# Europe                    5823.0                       536.0
# North America        173995947.0                  15420953.0
# Oceania               36177574.0                   3158066.0
# South America        865588126.0                  10228540.0
#
#                Acreage(Hectare)  Yield(Kg/Hectare)  number_of_countries
# Continent
# Africa                1439089.0          2142107.5                   38
# Asia                 10608319.0          1171871.4                   25
# Europe                     71.0           131870.9                    2
# North America         1581983.0          1082602.4                   22
# Oceania                490909.0           162419.1                    4
# South America        11369236.0           677192.7                   11

# %%
continent_names=df_Continent.index.to_list()
sns.lineplot(data=df_Continent,x="number_of_countries",y="Production (Tons)")
plt.xticks(df_Continent["number_of_countries"],continent_names,rotation=90)
plt.show()

# %% [markdown]
# DO CONTINENT WITH HIGHEST LAND PRODUCES MORE SUGARCANE?

# %% [markdown]
# PRODUCTION DISTRIBUTION BY CONTIENT

# %%
df_Continent["Production (Tons)"].plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='Production (Tons)'>

# %%
df_Continent.corr()
# Out:
#                             Production (Tons)  Production_per_Person_(Kg)  \
# Production (Tons)                    1.000000                    0.143100
# Production_per_Person_(Kg)           0.143100                    1.000000
# Acreage(Hectare)                     0.994897                    0.073059
# Yield(Kg/Hectare)                    0.091201                    0.541229
# number_of_countries                  0.109244                    0.526387
#
#                             Acreage(Hectare)  Yield(Kg/Hectare)  \
# Production (Tons)                   0.994897           0.091201
# Production_per_Person_(Kg)          0.073059           0.541229
# Acreage(Hectare)                    1.000000           0.111166
# Yield(Kg/Hectare)                   0.111166           1.000000
# number_of_countries                 0.132817           0.989712
#
#                             number_of_countries
# Production (Tons)                      0.109244
# Production_per_Person_(Kg)             0.526387
# Acreage(Hectare)                       0.132817
# Yield(Kg/Hectare)                      0.989712
# number_of_countries                    1.000000
